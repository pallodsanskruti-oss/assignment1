# %% [markdown]
# <a href="https://colab.research.google.com/github/pallodsanskruti-oss/assignment1/blob/main/celcius_to_ferhenheit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def celsius_to_fahrenheit(celsius):
  """Converts temperature from Celsius to Fahrenheit."""
  return (celsius * 9/5) + 32

# %%
celsius_temp = 25
fahrenheit_temp = celsius_to_fahrenheit(celsius_temp)
print(f"{celsius_temp}°C is equal to {fahrenheit_temp}°F")
# Out:
# 25°C is equal to 77.0°F
